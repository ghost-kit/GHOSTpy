# %%
# %matplotlib inline

from __future__ import absolute_import

import numpy as np

import ghostpy.Invariants.LShell as ls
import ghostpy.algorithms.convert as algx
import ghostpy.algorithms.common as algc

import ghostpy.data.VtkData as vdt
import cProfile, pstats, StringIO
import ghostpy.data.GpData as gpd
import ghostpy.plotting.FieldLinePlot as flplt
import ghostpy.Invariants.FieldLine as fl
import random as rnd
import csv
from parse import *

import matplotlib.pylab as plt
import time
import glob

# %%
def pointTest(pos=None, data=None):
    timings = []
    lstars = []
    for locs in pos:
        loc = algc.sphere_to_cart(r=locs[0], lam=locs[1], phi=locs[2])
        start = time.time()
        lsl = ls.LShell(start_loc=loc, data=data, error_tol=2e-6)
        stop = time.time()
        dur = stop - start
        timings.append(dur)
        lstar = lsl.l_star(res=1000)
        lstars.append(lstar)
        print ("LStar: {} -- {}".format(lstar, dur))
        
    return np.array(timings), np.array(lstars)

# %%
def convergeTest(pos=None, data=None):
    for loc in pos:
        lsl = ls.LShell(start_loc=loc, data=data, save_lines=True, error_tol=2e-6)
        lstar = lsl.l_star(res=10000)
        print ("LStar: {}".format(lstar))
        lsl.converge_lstar(tol=1e-3)
        lstar = lsl.l_star(res=1000)
        print ("LStar(C): {}".format(lstar))

# %%
def convergeTest2(pos=None, data=None):
    for loc in pos:
        lsl = ls.LShell(start_loc=loc, data=data, save_lines=True, error_tol=2e-6)
        lstar = lsl.l_star(res=10000)
        print ("LStar: {}".format(lstar))
        lsl.converge_p2(depth=3)
        lstar = lsl.l_star(res=10000)
        print("LStar(C): {}".format(lstar))

# %%
def process_stats(prof_lines=None, timeLine=None, keyLine=None, dataStartLine=None):
    assert prof_lines is not None
    assert timeLine is not None
    assert keyLine is not None
    assert dataStartLine is not None
    count = 0
    profile = {}
    keys = []
    pstring = "{file}:{line}({function})"
    for line in prof_lines:
        # print ("Count: {}".format(count))
        ls_prof = {}
        if count == timeLine:
            # print ("line: {}".format(count))
            # print ("{}".format(line))
            stats = line.split()
            time = stats[-2]
            profile['time'] = time
        elif count == keyLine:
            # print ("line: {}".format(count))
            # print ("{}".format(line))
            keys = line.split()
            # print ("Keys: {}".format(keys))
        elif count >= dataStartLine:
            # print ("line: {}".format(count))
            # print ("{}".format(line))
            stats = line.split()
            # print (stats)
            # print (len(stats))
            if len(stats) == 6:
                ls_prof[keys[0]] = stats[0]
                ls_prof[keys[1]]=stats[1]
                ls_prof[keys[2]]=stats[2]
                ls_prof[keys[3]]=stats[3]
                ls_prof[keys[4]]=stats[4]
                filestats = parse(pstring, stats[5])
                
                try:
                    profile[filestats['file']][filestats['function']] = ls_prof
                except:
                    try:
                        profile[filestats['file']] = {}
                        profile[filestats['file']][filestats['function']] = ls_prof
                    except:
                        pass
        count += 1
    
    return profile

# %%
outpath = "/Volumes/8TB Seagate/PhD Data/profiles/"
data = vdt.VtkData(filename="/Users/jjm390/src/ghostpy/ghostpy/unit_tests/test_data/WHIQuad.vts", vector='B')

# %%
r = np.linspace(start=2.4, stop=8.5, num=5000)
lam = np.linspace(start=-np.pi/3, stop=np.pi/3, num=5000)
phi = np.linspace(start=0, stop=np.pi*2, num=5000, endpoint=False)

cnt = 500

rs = np.random.choice(r, cnt)
lams = np.random.choice(lam, cnt)
phis = np.random.choice(phi, cnt)

ps = np.vstack([rs,lams,phis]).T

# %%
profile = cProfile.Profile()
profile.enable()
timings, lstars = pointTest(pos=ps, data=data)
profile.disable()

# ps1.print_stats()
# Out:
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (0.033764150625498618, 2.4424496382292751, -3.2546047772170028)
# /usr/local/lib/python2.7/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# /Users/jjm390/src/ghostpy/ghostpy/ghostpy/Invariants/FieldLine.py:680: RuntimeWarning: All-NaN slice encountered
#   n_k = np.nanmax([kf,kb], axis=0)
# B_mirror = 801.197863316
# K = 517.969047946
# Start Phi: 1.55697331912
# Dipole L: 11.3975030521
# ================
# 0.819702526094
# Relative B Error (IN): 0.0727492323426
# Relative B Error (OUT): -7.82130887198
# ...
# ================
# 0.833397430592
# Moving inner boundary in
# Relative B Error (IN): 0.719501418469
# Relative B Error (OUT): -2.28688212103
# ...
# ================
# 0.833397430592
# Moving inner boundary in
# Relative B Error (IN): 0.43709383283
# Relative B Error (OUT): -2.20172875432
# ...
# ================
# 0.833397430592
# Moving inner boundary in
# Relative B Error (IN): 3.01951304956
# Relative B Error (OUT): -1.4269536942
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 10.8779451052 -- 65.4362299442
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.2981232219616157, 3.4091609705835038, 3.4621369540483746)
# B_mirror = 279.620475775
# K = 155.83057672
# Start Phi: 0.977663633797
# Dipole L: 9.30931239763
# ================
# 0.781656187543
# Moving inner boundary in
# Relative B Error (IN): 0.784900135542
# Relative B Error (OUT): -0.226826162861
# ...
# ================
# 0.792485184068
# Moving inner boundary in
# Relative B Error (IN): 1.03318595213
# Relative B Error (OUT): -0.0516065171587
# ...
# ================
# 0.792485184068
# Moving inner boundary in
# Relative B Error (IN): 0.588143000712
# Relative B Error (OUT): -2.66300649499
# ...
# ================
# 0.792485184068
# Moving inner boundary in
# Relative B Error (IN): 0.0959540038451
# Relative B Error (OUT): -0.271917387494
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 8.69228685476 -- 45.2513000965
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-1.2628588921038473, 3.0871457900234005, 2.6592044358954201)
# B_mirror = 592.299057387
# K = 197.834673161
# Start Phi: 1.95909717878
# Dipole L: 7.11224667868
# ================
# 0.734788574128
# Moving inner boundary in
# Relative B Error (IN): 1.56987338056
# Relative B Error (OUT): -1.19323253694
# ...
# ================
# 0.724300326463
# Moving inner boundary in
# Relative B Error (IN): 0.477359590836
# Relative B Error (OUT): -3.06000202319
# ...
# ================
# 0.724300326463
# Moving inner boundary in
# Relative B Error (IN): 3.48254149245
# Relative B Error (OUT): -1.99606983137
# ...
# ================
# 0.724300326463
# Moving inner boundary in
# Relative B Error (IN): 2.1531011181
# Relative B Error (OUT): -0.831045702204
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 6.87332533975 -- 35.4898710251
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (4.083952511910045, 3.6279426496460134, 3.242217551537022)
# B_mirror = 156.660266152
# K = 63.8026352365
# Start Phi: 0.72633622151
# Dipole L: 8.90893077112
# ================
# 0.774453295222
# Moving inner boundary in
# Relative B Error (IN): 0.301528041985
# Relative B Error (OUT): -0.557759696263
# ...
# ================
# 0.775633924899
# Moving inner boundary in
# Relative B Error (IN): 0.0354152480593
# Relative B Error (OUT): -1.66986131862
# ...
# ================
# 0.775633924899
# Moving inner boundary in
# Relative B Error (IN): 0.390213409307
# Relative B Error (OUT): -0.0800536293817
# ...
# ================
# 0.775633924899
# Moving inner boundary in
# Relative B Error (IN): 0.40262523627
# Relative B Error (OUT): -0.454671505291
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 8.18591706763 -- 42.1661729813
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-5.7197629540497079, 4.0468211584861438, 3.2852671912334666)
# B_mirror = 98.0192269522
# K = 76.5737137912
# Start Phi: 2.52584049349
# Dipole L: 9.84421604434
# ================
# 0.795186580886
# Relative B Error (IN): 0.151220306601
# Relative B Error (OUT): -0.00554793804095
# ...
# ================
# 0.840193794819
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.129702566383
# Relative B Error (OUT): -0.188984955073
# ...
# ================
# 0.840193794819
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.262542077557
# Relative B Error (OUT): -0.136739881199
# ...
# ================
# 0.840193794819
# Moving inner boundary in
# Relative B Error (IN): 0.0196512538415
# Relative B Error (OUT): -0.0521061605938
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 11.0699910763 -- 69.1219410896
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-5.351822228895422, -2.2207379651641057, 0.99396806076844046)
# B_mirror = 155.144016703
# K = 8.87210233708
# Start Phi: 3.53492005382
# Dipole L: 6.09314768545
# ================
# 0.664495726082
# Moving inner boundary in
# Relative B Error (IN): 0.152658110538
# Relative B Error (OUT): -0.0010710572075
# ...
# ================
# 0.727650722984
# Moving inner boundary in
# Relative B Error (IN): 0.285362965196
# Relative B Error (OUT): -0.160549549384
# ...
# ================
# 0.727650722984
# Moving inner boundary in
# Relative B Error (IN): 0.3952642441
# Relative B Error (OUT): -0.613129308287
# ...
# ================
# 0.727650722984
# Moving inner boundary in
# Relative B Error (IN): 0.040718588209
# Relative B Error (OUT): -0.678098220007
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 6.32251961777 -- 25.1651721001
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.2585174815742173, -3.0776713708928365, -1.4590163633303019)
# B_mirror = 203.837766012
# K = 17.8864012664
# Start Phi: 3.76739791018
# Dipole L: 5.88620831786
# ================
# 0.665221207711
# Moving inner boundary in
# Relative B Error (IN): 0.0405947745271
# Relative B Error (OUT): -0.0639101113445
# ...
# ================
# 0.681901584108
# Moving inner boundary in
# Relative B Error (IN): 1.21355648706
# Relative B Error (OUT): -0.363620419075
# ...
# ================
# 0.681901584108
# Moving inner boundary in
# Relative B Error (IN): 1.60133117941
# Relative B Error (OUT): -0.985365245402
# ...
# ================
# 0.681901584108
# Moving inner boundary in
# Relative B Error (IN): 0.186617224119
# Relative B Error (OUT): -0.357443281734
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.94364094383 -- 21.0966188908
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-2.5796087663609404, -2.8385338793738275, 2.0955455813091106)
# B_mirror = 486.130490688
# K = 90.3492947442
# Start Phi: 3.97474302532
# Dipole L: 5.75111125335
# ================
# 0.659558179438
# Moving inner boundary in
# Relative B Error (IN): 0.603676419329
# Relative B Error (OUT): -0.659402396122
# ...
# ================
# 0.672518752415
# Moving inner boundary in
# Relative B Error (IN): 3.5322161455
# Relative B Error (OUT): -3.2863247644
# ...
# ================
# 0.672518752415
# Moving inner boundary in
# Relative B Error (IN): 1.37872840895
# Relative B Error (OUT): -0.358384479783
# ...
# ================
# 0.672518752415
# Moving inner boundary in
# Relative B Error (IN): 1.90124459607
# Relative B Error (OUT): -0.056537254954
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.62792437342 -- 19.2415571213
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-5.1006000940087874, 3.2730187131295514, 3.7182451302465482)
# B_mirror = 127.316283978
# K = 124.289623495
# Start Phi: 2.5710794277
# Dipole L: 10.1267455755
# ================
# 0.80429445894
# Relative B Error (IN): 0.460051151955
# Relative B Error (OUT): -0.096615166563
# ...
# ================
# 0.845684745259
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0201088011794
# Relative B Error (OUT): -0.333835377266
# ...
# ================
# 0.845684745259
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.408747776821
# Relative B Error (OUT): -0.359426535684
# ...
# ================
# 0.845684745259
# Moving inner boundary in
# Relative B Error (IN): 0.0335571587377
# Relative B Error (OUT): -0.0975533467553
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 11.779406019 -- 75.2131540775
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-2.9349779261671403, -2.9571909848771836, 1.4482795016827734)
# B_mirror = 411.236225935
# K = 35.4743200146
# Start Phi: 3.93076072817
# Dipole L: 4.97856416333
# ================
# 0.597595430122
# Moving inner boundary in
# Relative B Error (IN): 0.909635114047
# Relative B Error (OUT): -0.0868281899287
# ...
# ================
# 0.609077446697
# Moving inner boundary in
# Relative B Error (IN): 2.29972207622
# Relative B Error (OUT): -1.52531965238
# ...
# ================
# 0.609077446697
# Moving inner boundary in
# Relative B Error (IN): 0.0215430447216
# Relative B Error (OUT): -1.21475408554
# ...
# ================
# 0.609077446697
# Moving inner boundary in
# Relative B Error (IN): 1.76654463789
# Relative B Error (OUT): -0.149189665723
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 4.89368868111 -- 12.9124128819
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.2678910039517652, -2.2678910039517657, -0.33648759745334222)
# B_mirror = 921.650056809
# K = 2.72483580724
# Start Phi: 5.49778714378
# Dipole L: 3.2751885663
# ================
# 0.47081683748
# Moving inner boundary in
# Relative B Error (IN): 0.359153474114
# Relative B Error (OUT): -1.44829829597
# ...
# ================
# 0.433600855363
# Moving inner boundary in
# Relative B Error (IN): 1.71524383439
# Relative B Error (OUT): -1.07787362108
# ...
# ================
# 0.433600855363
# Moving inner boundary in
# Relative B Error (IN): 1.31452895192
# Relative B Error (OUT): -1.34255192326
# ...
# ================
# 0.433600855363
# Moving inner boundary in
# Relative B Error (IN): 1.78335050508
# Relative B Error (OUT): -0.420643123622
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 3.25355801565 -- 4.89142608643
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.0423729675806603, -5.1889185628868608, -3.1405216423766502)
# B_mirror = 127.47949445
# K = 57.9242222027
# Start Phi: 4.18208814046
# Dipole L: 8.68972368284
# ================
# 0.768545266527
# Moving inner boundary in
# Relative B Error (IN): 0.0235288595778
# Relative B Error (OUT): -0.00929347496881
# ...
# ================
# 0.792900779099
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0412456382404
# Relative B Error (OUT): -0.162915908653
# ...
# ================
# 0.792900779099
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0539495130216
# Relative B Error (OUT): -0.796806561085
# ...
# ================
# 0.792900779099
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.790864863857
# Relative B Error (OUT): -0.74784524141
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 8.9661992028 -- 51.8590800762
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-1.1971465878234211, 3.223161976038813, 1.573664388050801)
# B_mirror = 744.897244867
# K = 72.7027266413
# Start Phi: 1.92642461518
# Dipole L: 4.59898133116
# ================
# 0.604748271842
# Moving inner boundary in
# Relative B Error (IN): 6.23974769933
# Relative B Error (OUT): -1.21363176747
# ...
# ================
# 0.574760461025
# Moving inner boundary in
# Relative B Error (IN): 1.33016083122
# Relative B Error (OUT): -0.99339024584
# ...
# ================
# 0.574760461025
# Moving inner boundary in
# Relative B Error (IN): 0.0467505915184
# Relative B Error (OUT): -0.0461067454742
# ...
# ================
# 0.574760461025
# Moving inner boundary in
# Relative B Error (IN): 8.12504765948
# Relative B Error (OUT): -2.72162618206
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 4.41548714505 -- 10.2409520149
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (5.6911370501689769, -3.3080670157000784, -4.0008303648913426)
# B_mirror = 80.8329781518
# K = 12.3047181192
# Start Phi: 5.75665437844
# Dipole L: 11.3401487593
# ================
# 0.826358905178
# Moving inner boundary in
# Relative B Error (IN): 0.177749455913
# Relative B Error (OUT): -0.0535178015948
# ...
# ================
# 0.819017133283
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0558029511565
# Relative B Error (OUT): -0.0212453199776
# ...
# ================
# 0.819017133283
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.114080071081
# Relative B Error (OUT): -0.0759664925638
# ...
# ================
# 0.819017133283
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.00216747698775
# Relative B Error (OUT): -0.0417741542559
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 10.1263810249 -- 48.8743209839
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (0.20922435280095353, -1.57645808460698, -2.469094985018248)
# B_mirror = 2027.74648579
# K = 789.991353694
# Start Phi: 4.84433587184
# Dipole L: 10.0969541164
# ================
# 0.801247821536
# Moving inner boundary in
# Moving outer boundary out
# Relative B Error (IN): 16.6512453339
# Relative B Error (OUT): -5.37913969127
# ...
# ================
# 0.803694285461
# Moving inner boundary in
# Relative B Error (IN): 4.45414453109
# Relative B Error (OUT): -9.31562548637
# ...
# ================
# 0.803694285461
# Moving inner boundary in
# Relative B Error (IN): 4.07964208004
# Relative B Error (OUT): -40.836582044
# ...
# ================
# 0.803694285461
# Moving inner boundary in
# Moving outer boundary out
# Relative B Error (IN): 13.6819277291
# Relative B Error (OUT): -2.46829641845
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 9.66672325256 -- 48.9003050327
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (3.1498028554670046, -1.438901667856245, -1.5726562597193283)
# B_mirror = 660.337246677
# K = 57.7046869288
# Start Phi: 5.85467206923
# Dipole L: 4.6240354875
# ================
# 0.621219983111
# Moving inner boundary in
# Relative B Error (IN): 4.16552266979
# Relative B Error (OUT): -1.80783334012
# ...
# ================
# 0.591939355169
# Moving inner boundary in
# Relative B Error (IN): 0.425397207884
# Relative B Error (OUT): -3.91397283152
# ...
# ================
# 0.591939355169
# Moving inner boundary in
# Relative B Error (IN): 0.718293391411
# Relative B Error (OUT): -2.79016444274
# ...
# ================
# 0.591939355169
# Moving inner boundary in
# Relative B Error (IN): 0.352947030712
# Relative B Error (OUT): -1.92857696808
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 4.49818894586 -- 10.7074530125
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-2.7683654679003791, -0.57874509651104411, -2.7762613286271334)
# B_mirror = 761.757462016
# K = 306.355065847
# Start Phi: 3.34768113167
# Dipole L: 7.79113148129
# ================
# 0.740641132435
# Moving inner boundary in
# Relative B Error (IN): 3.60177170648
# Relative B Error (OUT): -1.47659942862
# ...
# ================
# 0.75044042483
# Moving inner boundary in
# Relative B Error (IN): 11.7649087233
# Relative B Error (OUT): -1.03380062715
# ...
# ================
# 0.75044042483
# Moving inner boundary in
# Relative B Error (IN): 0.554968506995
# Relative B Error (OUT): -0.174918843788
# ...
# ================
# 0.75044042483
# Moving inner boundary in
# Relative B Error (IN): 1.82315219729
# Relative B Error (OUT): -3.0526118381
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 7.77145532337 -- 41.6146128178
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-2.4613223922768395, -2.4987209466850913, 0.71118101652436416)
# B_mirror = 675.284096453
# K = 10.1360374328
# Start Phi: 3.93453063936
# Dipole L: 3.73500676667
# ================
# 0.521882120816
# Moving inner boundary in
# Relative B Error (IN): 1.19417133199
# Relative B Error (OUT): -2.6197903406
# ...
# ================
# 0.518209086465
# Moving inner boundary in
# Relative B Error (IN): 0.368045636126
# Relative B Error (OUT): -1.16612334238
# ...
# ================
# 0.518209086465
# Moving inner boundary in
# Relative B Error (IN): 2.70766116745
# Relative B Error (OUT): -0.416104146884
# ...
# ================
# 0.518209086465
# Moving inner boundary in
# Relative B Error (IN): 0.209063728937
# Relative B Error (OUT): -0.802036680194
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 3.6902214371 -- 6.8075940609
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.1280536781555264, -5.6730102325422598, -3.8596929405914842)
# B_mirror = 98.9073138205
# K = 71.6201568916
# Start Phi: 4.20847751875
# Dipole L: 10.4604199524
# ================
# 0.80500371572
# Moving inner boundary in
# Relative B Error (IN): 0.0841619702218
# Relative B Error (OUT): -0.202757660509
# ...
# ================
# 0.836786796112
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0832464138108
# Relative B Error (OUT): -0.0326602857379
# ...
# ================
# 0.836786796112
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0328996642511
# Relative B Error (OUT): -0.148545918494
# ...
# ================
# 0.836786796112
# Moving inner boundary in
# Relative B Error (IN): 0.05988728919
# Relative B Error (OUT): -0.503781105955
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 10.9836086847 -- 66.1332690716
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (1.768576722020438, -4.1729840444917068, 4.3458185068884303)
# B_mirror = 183.313241305
# K = 156.201427468
# Start Phi: 5.11325620298
# Dipole L: 12.773519609
# ================
# 0.850402170509
# Moving inner boundary in
# Relative B Error (IN): 0.55617100775
# Relative B Error (OUT): -0.249428895231
# ...
# ================
# 0.839980218299
# Moving inner boundary in
# Relative B Error (IN): 0.212953177026
# Relative B Error (OUT): -0.316696686097
# ...
# ================
# 0.839980218299
# Moving inner boundary in
# Relative B Error (IN): 0.951891496374
# Relative B Error (OUT): -0.483971144758
# ...
# ================
# 0.839980218299
# Moving inner boundary in
# Relative B Error (IN): 0.301856926175
# Relative B Error (OUT): -0.346009934258
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 11.9670181358 -- 68.2430570126
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.3069403104097628, -1.2336937487807591, -3.9094153288571012)
# B_mirror = 232.756929843
# K = 215.215560568
# Start Phi: 3.42056608123
# Dipole L: 10.1372201564
# ================
# 0.800450222399
# Moving inner boundary in
# Relative B Error (IN): 0.063711442752
# Relative B Error (OUT): -0.221938408927
# ...
# ================
# 0.844474799783
# Moving inner boundary in
# Relative B Error (IN): 0.0765000925797
# Relative B Error (OUT): -0.341009461307
# ...
# ================
# 0.844474799783
# Moving inner boundary in
# Relative B Error (IN): 0.713307886564
# Relative B Error (OUT): -0.700366491648
# ...
# ================
# 0.844474799783
# Moving inner boundary in
# Relative B Error (IN): 1.37251432626
# Relative B Error (OUT): -0.0238497932531
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 11.5286864288 -- 77.6741149426
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (4.9909186764210842, 2.1597633716017803, 5.9035228925160173)
# Invalid line initiation
# Starting Location: [ 4.99091868  2.15976337  5.90352289]
# LStar: nan -- 0.0536749362946
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.4835795621551249, -0.50294307960983242, 2.6179101216753509)
# B_mirror = 1003.88225184
# K = 310.825885216
# Start Phi: 6.08338001441
# Dipole L: 7.45620514198
# ================
# 0.735938041403
# Moving inner boundary in
# Relative B Error (IN): 2.24304361809
# Relative B Error (OUT): -9.00169035946
# ...
# ================
# 0.714449575009
# Moving inner boundary in
# Relative B Error (IN): 1.36243615676
# Relative B Error (OUT): -1.93651183936
# ...
# ================
# 0.714449575009
# Moving inner boundary in
# Relative B Error (IN): 2.11682934371
# Relative B Error (OUT): -7.13797479707
# ...
# ================
# 0.714449575009
# Moving inner boundary in
# Relative B Error (IN): 1.38884766512
# Relative B Error (OUT): -0.983144868378
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 7.14194938288 -- 36.6548149586
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.0236143212331261, 2.4317434992363456, 0.23845600929242414)
# B_mirror = 515.138101656
# K = 1.22386171819
# Start Phi: 2.46426527748
# Dipole L: 3.89702060792
# ================
# 0.557180366428
# Moving inner boundary in
# Relative B Error (IN): 0.622492833334
# Relative B Error (OUT): -0.542871004735
# ...
# ================
# 0.541362388062
# Moving inner boundary in
# Relative B Error (IN): 0.656440663086
# Relative B Error (OUT): -0.150174863934
# ...
# ================
# 0.541362388062
# Moving inner boundary in
# Relative B Error (IN): 0.339259192416
# Relative B Error (OUT): -0.410620292125
# ...
# ================
# 0.541362388062
# Moving inner boundary in
# Relative B Error (IN): 1.77595035507
# Relative B Error (OUT): -3.09193387282
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 3.93219381046 -- 7.5277428627
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (1.1168035110044139, 1.5911748927883342, 1.7903785091755415)
# B_mirror = 2550.74423032
# K = 323.543510319
# Start Phi: 0.958814077876
# Dipole L: 4.8850470756
# ================
# 0.628215020762
# Moving inner boundary in
# Relative B Error (IN): 32.0029316968
# Relative B Error (OUT): -16.7117934016
# ...
# ================
# 0.599144845757
# Moving inner boundary in
# Relative B Error (IN): 9.64702890954
# Relative B Error (OUT): -11.6816247865
# ...
# ================
# 0.599144845757
# Moving inner boundary in
# Relative B Error (IN): 12.4230375863
# Relative B Error (OUT): -1.28847198398
# ...
# ================
# 0.599144845757
# Moving inner boundary in
# Relative B Error (IN): 11.2848195092
# Relative B Error (OUT): -2.49731418551
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 4.57653344285 -- 11.4351911545
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (0.081716281640738853, -2.5001773138706715, 0.81006859986387592)
# B_mirror = 2016.84444483
# K = 43.3833949592
# Start Phi: 4.74506154398
# Dipole L: 2.90830627616
# ================
# 0.410906028999
# Moving inner boundary in
# Relative B Error (IN): 7.28657710941
# Relative B Error (OUT): -0.22210061745
# ...
# ================
# 0.365316216673
# Moving inner boundary in
# Relative B Error (IN): 13.4984050534
# Relative B Error (OUT): -2.99778496905
# ...
# ================
# 0.365316216673
# Moving inner boundary in
# Relative B Error (IN): 12.6487658638
# Relative B Error (OUT): -2.28000534846
# ...
# ================
# 0.365316216673
# Moving inner boundary in
# Relative B Error (IN): 0.367655267387
# Relative B Error (OUT): -21.7154668997
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 2.85011353607 -- 3.76781702042
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.2164016581634662, 3.4881108047504652, 3.5236934648447717)
# B_mirror = 168.850655483
# K = 129.209933405
# Start Phi: 2.4504422698
# Dipole L: 9.85701669213
# ================
# 0.801098838386
# Moving inner boundary in
# Relative B Error (IN): 0.27969052891
# Relative B Error (OUT): -0.0132034085926
# ...
# ================
# 0.821417708611
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.173071172677
# Relative B Error (OUT): -0.138673863627
# ...
# ================
# 0.821417708611
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.200689480155
# Relative B Error (OUT): -0.189017637195
# ...
# ================
# 0.821417708611
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.144045684457
# Relative B Error (OUT): -0.476555030837
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 10.2204027336 -- 63.082777977
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (3.0495975684907783, 4.1315405004401278, 2.5752240204333323)
# B_mirror = 201.722333369
# K = 55.2859900843
# Start Phi: 0.934937973708
# Dipole L: 7.3635285697
# ================
# 0.729841769557
# Moving inner boundary in
# Relative B Error (IN): 0.0741896763231
# Relative B Error (OUT): -0.0551890400783
# ...
# ================
# 0.728261693155
# Moving inner boundary in
# Relative B Error (IN): 0.0232825107346
# Relative B Error (OUT): -0.508331411625
# ...
# ================
# 0.728261693155
# Moving inner boundary in
# Relative B Error (IN): 4.03207043563
# Relative B Error (OUT): -0.598371107316
# ...
# ================
# 0.728261693155
# Moving inner boundary in
# Relative B Error (IN): 0.102930393595
# Relative B Error (OUT): -0.925907321236
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 6.97551117133 -- 36.9626538754
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-6.5022152740531984, 3.0597102567221683, -0.2183447951203816)
# B_mirror = 73.8986232537
# K = 0.046760550453
# Start Phi: 2.70176968209
# Dipole L: 6.85060340405
# ================
# 0.704732701797
# Moving inner boundary in
# Relative B Error (IN): 0.000650873112093
# Relative B Error (OUT): -0.00811101967942
# ...
# ================
# 0.82750525643
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0177381547639
# Relative B Error (OUT): -0.0962062247769
# ...
# ================
# 0.82750525643
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0296871423038
# Relative B Error (OUT): -0.0751854004965
# ...
# ================
# 0.82750525643
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.020142490187
# Relative B Error (OUT): -0.0740959779469
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 8.47900002247 -- 45.8678398132
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-5.6209603141786397, 1.1603621825793877, 0.06132036877683858)
# B_mirror = 153.980620057
# K = 0.401238268233
# Start Phi: 2.93801744964
# Dipole L: 5.62852289707
# ================
# 0.648196303547
# Moving inner boundary in
# Relative B Error (IN): 0.000708276432931
# Relative B Error (OUT): -0.0137204990458
# ...
# ================
# 0.703855517026
# Moving inner boundary in
# Relative B Error (IN): 0.00298254145108
# Relative B Error (OUT): -0.0278542960969
# ...
# ================
# 0.703855517026
# Moving inner boundary in
# Relative B Error (IN): 0.0160796330121
# Relative B Error (OUT): -0.015500023184
# ...
# ================
# 0.703855517026
# Moving inner boundary in
# Relative B Error (IN): 0.0617476663455
# Relative B Error (OUT): -0.0022682648422
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 6.07531808308 -- 23.1084799767
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.9915554323850051, -6.3358509187224472, 0.86330837951285588)
# B_mirror = 61.3458172355
# K = 5.80108990871
# Start Phi: 4.04511470076
# Dipole L: 8.28011221802
# ================
# 0.768394156597
# Relative B Error (IN): 0.00369505685946
# Relative B Error (OUT): -0.132079673455
# ...
# ================
# 0.84490127676
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0170847513724
# Relative B Error (OUT): -0.0876205251461
# ...
# ================
# 0.84490127676
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0491725944939
# Relative B Error (OUT): -0.126355370564
# ...
# ================
# 0.84490127676
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.00838149210821
# Relative B Error (OUT): -0.0103607133206
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 9.44639209051 -- 58.8760378361
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (3.9965005075642166, -2.5503684426809525, -1.029741964645118)
# B_mirror = 295.336493261
# K = 11.1815415776
# Start Phi: 5.71518535541
# Dipole L: 5.19843845868
# ================
# 0.630377757026
# Moving inner boundary in
# Relative B Error (IN): 1.01638272406
# Relative B Error (OUT): -0.0309889328634
# ...
# ================
# 0.646548726466
# Moving inner boundary in
# Relative B Error (IN): 1.29595121919
# Relative B Error (OUT): -1.7445889439
# ...
# ================
# 0.646548726466
# Moving inner boundary in
# Relative B Error (IN): 1.03408326266
# Relative B Error (OUT): -0.164193740008
# ...
# ================
# 0.646548726466
# Moving inner boundary in
# Relative B Error (IN): 0.263831733283
# Relative B Error (OUT): -0.669638479
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.10511353523 -- 14.492702961
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-1.2047863573125093, -1.8620311136515164, 1.7155726594892291)
# B_mirror = 2071.44707599
# K = 227.460979827
# Start Phi: 4.13810584331
# Dipole L: 4.49478696159
# ================
# 0.590253550696
# Moving inner boundary in
# Relative B Error (IN): 3.33010882545
# Relative B Error (OUT): -4.18150908304
# ...
# ================
# 0.559345838818
# Moving inner boundary in
# Relative B Error (IN): 19.8397018599
# Relative B Error (OUT): -4.87614953105
# ...
# ================
# 0.559345838818
# Moving inner boundary in
# Relative B Error (IN): 8.05233759097
# Relative B Error (OUT): -14.5145263908
# ...
# ================
# 0.559345838818
# Moving inner boundary in
# Relative B Error (IN): 0.884554519212
# Relative B Error (OUT): -14.3152912861
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 4.30340467686 -- 9.40871191025
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.3531211973503483, 0.28525902021769739, 2.2862057994344034)
# B_mirror = 1303.89523675
# K = 295.961069251
# Start Phi: 0.120637157898
# Dipole L: 6.30362134916
# ================
# 0.707555363132
# Moving inner boundary in
# Relative B Error (IN): 4.8783404073
# Relative B Error (OUT): -1.60891849937
# ...
# ================
# 0.680089394497
# Moving inner boundary in
# Relative B Error (IN): 1.14085454672
# Relative B Error (OUT): -0.440421078967
# ...
# ================
# 0.680089394497
# Moving inner boundary in
# Relative B Error (IN): 4.29599620683
# Relative B Error (OUT): -0.4113768468
# ...
# ================
# 0.680089394497
# Moving inner boundary in
# Relative B Error (IN): 1.83046714102
# Relative B Error (OUT): -0.00276426208825
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.88243490544 -- 22.392592907
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-2.4206446974541822, -0.99376597649033016, 1.4353153573571427)
# B_mirror = 1512.41686483
# K = 107.909813272
# Start Phi: 3.53115014263
# Dipole L: 3.89293084233
# ================
# 0.522453156718
# Moving inner boundary in
# Relative B Error (IN): 9.01642074101
# Relative B Error (OUT): -0.384714131764
# ...
# ================
# 0.527658731797
# Moving inner boundary in
# Relative B Error (IN): 22.0229241755
# Relative B Error (OUT): -14.201590696
# ...
# ================
# 0.527658731797
# Moving inner boundary in
# Relative B Error (IN): 21.0654965145
# Relative B Error (OUT): -8.03829620803
# ...
# ================
# 0.527658731797
# Moving inner boundary in
# Relative B Error (IN): 21.4143428511
# Relative B Error (OUT): -20.2897275895
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 3.70695801751 -- 6.96275687218
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.0090886034899174, -3.8194781268469988, 0.53486136235953863)
# B_mirror = 269.191077687
# K = 4.39545713092
# Start Phi: 4.04511470076
# Dipole L: 4.9734959482
# ================
# 0.612400068343
# Moving inner boundary in
# Relative B Error (IN): 0.167864973045
# Relative B Error (OUT): -0.18848977866
# ...
# ================
# 0.628522022757
# Moving inner boundary in
# Relative B Error (IN): 0.13757052779
# Relative B Error (OUT): -0.69122594939
# ...
# ================
# 0.628522022757
# Moving inner boundary in
# Relative B Error (IN): 1.32531995743
# Relative B Error (OUT): -0.828235191632
# ...
# ================
# 0.628522022757
# Moving inner boundary in
# Relative B Error (IN): 0.131150205103
# Relative B Error (OUT): -0.0955528325563
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.01387743777 -- 13.8165659904
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (3.4011544563466014, 4.8071798823177403, -2.9069591306038576)
# B_mirror = 132.308046417
# K = 39.1835026229
# Start Phi: 0.955044166691
# Dipole L: 8.3351427727
# ================
# 0.759305141537
# Moving inner boundary in
# Relative B Error (IN): 0.173867967759
# Relative B Error (OUT): -0.0980916432096
# ...
# ================
# 0.771010082174
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.567952061016
# Relative B Error (OUT): -0.0137621114962
# ...
# ================
# 0.771010082174
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.00654903756507
# Relative B Error (OUT): -0.026503258089
# ...
# ================
# 0.771010082174
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.174649657933
# Relative B Error (OUT): -0.123162443512
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 7.90428893906 -- 42.9619519711
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.5345074359047861, -0.6558479562507098, 5.3038077174751885)
# Invalid line initiation
# Starting Location: [-3.53450744 -0.65584796  5.30380772]
# LStar: nan -- 0.097599029541
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.5416396301219657, -6.0392391684434594, 4.1265791968089216)
# B_mirror = 94.506111803
# K = 64.133830392
# Start Phi: 5.11074292886
# Dipole L: 12.487454484
# ================
# 0.853636432179
# Moving inner boundary in
# Relative B Error (IN): 0.0129074506339
# Relative B Error (OUT): -0.0252322285999
# ...
# ================
# 0.847284494957
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0255068705032
# Relative B Error (OUT): -0.309521940516
# ...
# ================
# 0.847284494957
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.242556151785
# Relative B Error (OUT): -0.530545767274
# ...
# ================
# 0.847284494957
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0935502122423
# Relative B Error (OUT): -0.134162109568
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 11.7112269301 -- 69.3382949829
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-7.4522187609551054, -3.2582728910621075, -0.57170924668998069)
# B_mirror = 52.9375747931
# K = 0.0202473667659
# Start Phi: 3.55376960974
# Dipole L: 7.89965758475
# ================
# 0.749098795701
# Relative B Error (IN): 0.00831235573544
# Relative B Error (OUT): -0.0297100344893
# ...
# ================
# 0.849610993217
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0291269826837
# Relative B Error (OUT): -0.00183972893073
# ...
# ================
# 0.849610993217
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.000866635121291
# Relative B Error (OUT): -0.0100933010742
# ...
# ================
# 0.849610993217
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0345949185776
# Relative B Error (OUT): -0.0316094624285
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 9.73220218521 -- 58.2183051109
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (3.4467967465426299, 5.7619159630300496, -2.2490977614832044)
# B_mirror = 100.685956728
# K = 14.060567029
# Start Phi: 1.03169902744
# Dipole L: 8.11209592398
# ================
# 0.756464203883
# Moving inner boundary in
# Relative B Error (IN): 0.310445866994
# Relative B Error (OUT): -0.36461180423
# ...
# ================
# 0.780274105902
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.139272772289
# Relative B Error (OUT): -0.20826008275
# ...
# ================
# 0.780274105902
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.135825041788
# Relative B Error (OUT): -0.272347704046
# ...
# ================
# 0.780274105902
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.425987672731
# Relative B Error (OUT): -0.625569572407
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 7.79131633792 -- 41.3506789207
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-1.6348957989724762, 3.2489331256287879, 1.9752493845678021)
# B_mirror = 570.641103913
# K = 92.0680506192
# Start Phi: 2.03700867659
# Dipole L: 5.40468340127
# ================
# 0.63659384489
# Moving inner boundary in
# Relative B Error (IN): 0.0055793821366
# Relative B Error (OUT): -0.279820929615
# ...
# ================
# 0.636817473013
# Moving inner boundary in
# Relative B Error (IN): 0.349951888445
# Relative B Error (OUT): -0.24205290757
# ...
# ================
# 0.636817473013
# Moving inner boundary in
# Relative B Error (IN): 5.12819918862
# Relative B Error (OUT): -1.91703443841
# ...
# ================
# 0.636817473013
# Moving inner boundary in
# Relative B Error (IN): 4.57443076543
# Relative B Error (OUT): -1.27685979865
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.24589329906 -- 16.7238090038
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (4.6689144395786029, -1.1987734783745296, 1.4611704581630571)
# B_mirror = 274.41294828
# K = 20.8500607833
# Start Phi: 6.03185789489
# Dipole L: 5.64181884954
# ================
# 0.660714548883
# Moving inner boundary in
# Relative B Error (IN): 0.941971408692
# Relative B Error (OUT): -0.135192846153
# ...
# ================
# 0.648705667254
# Moving inner boundary in
# Relative B Error (IN): 1.14869446298
# Relative B Error (OUT): -0.0664775794593
# ...
# ================
# 0.648705667254
# Moving inner boundary in
# Relative B Error (IN): 0.520152161013
# Relative B Error (OUT): -0.531382215401
# ...
# ================
# 0.648705667254
# Moving inner boundary in
# Relative B Error (IN): 0.315854776545
# Relative B Error (OUT): -3.14420116984
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.49131027236 -- 17.8407568932
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-2.0536733074027382, -1.5439602672690618, -0.86545553912386197)
# B_mirror = 1718.22225623
# K = 38.71978489
# Start Phi: 3.78624746611
# Dipole L: 3.01674850604
# ================
# 0.413990101308
# Moving inner boundary in
# Relative B Error (IN): 2.2677937243
# Relative B Error (OUT): -3.48852793342
# ...
# ================
# 0.388087939902
# Moving inner boundary in
# Relative B Error (IN): 6.4125766418
# Relative B Error (OUT): -4.46490079479
# ...
# ================
# 0.388087939902
# Moving inner boundary in
# Relative B Error (IN): 1.98241031963
# Relative B Error (OUT): -1.64125835285
# ...
# ================
# 0.388087939902
# Moving inner boundary in
# Relative B Error (IN): 2.01236942549
# Relative B Error (OUT): -0.950772269872
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 2.92772123503 -- 4.10137891769
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.5432595778338953, 4.9366058374387194, -4.1007312744684654)
# B_mirror = 94.6386559736
# K = 83.5201314299
# Start Phi: 2.31472546716
# Dipole L: 11.3788965621
# ================
# 0.82592897252
# Moving inner boundary in
# Relative B Error (IN): 0.0473753954119
# Relative B Error (OUT): -0.159840610539
# ...
# ================
# 0.848844986162
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.00793611055795
# Relative B Error (OUT): -0.0526860328238
# ...
# ================
# 0.848844986162
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.128059780013
# Relative B Error (OUT): -0.163777952805
# ...
# ================
# 0.848844986162
# Moving inner boundary in
# Relative B Error (IN): 0.950699872342
# Relative B Error (OUT): -0.409411396134
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 11.6136583298 -- 80.4327769279
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.3308629574521258, -6.3241982425653642, 3.4439303054711865)
# B_mirror = 98.7908844433
# K = 48.1283554033
# Start Phi: 5.06550399465
# Dipole L: 10.7931886679
# ================
# 0.817421517968
# Moving inner boundary in
# Relative B Error (IN): 0.0436956363597
# Relative B Error (OUT): -0.034097532346
# ...
# ================
# 0.816169091658
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.132810968318
# Relative B Error (OUT): -0.359979855404
# ...
# ================
# 0.816169091658
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.369732702246
# Relative B Error (OUT): -0.00766172582873
# ...
# ================
# 0.816169091658
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.235818423092
# Relative B Error (OUT): -0.230996120373
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 10.3592678591 -- 56.8841462135
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-1.9420397761284085, 1.9765100296000155, 4.6497424245756553)
# B_mirror = 358.709899189
# K = 1196.12116382
# Start Phi: 2.34739803076
# Dipole L: 24.2890081109
# ================
# 0.946194572357
# Out on EPS convergence
# Low: None
# High: None
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# Line Failed to Add in 4 line convergence
# Failure Mode: -999
# Phi: 0.0
# Est. L: 24.2890081109
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: nan -- 17.5952599049
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (6.749882409293809, 1.7692875943295918, 2.0356278557274736)
# B_mirror = 107.795006746
# K = 16.2789072148
# Start Phi: 0.256353960533
# Dipole L: 8.6458962769
# ================
# 0.789077169259
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.310252851066
# Relative B Error (OUT): -0.00999509570318
# ...
# ================
# 0.771560320729
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.958797490223
# Relative B Error (OUT): -0.105768772528
# ...
# ================
# 0.771560320729
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.262105039634
# Relative B Error (OUT): -0.149563839596
# ...
# ================
# 0.771560320729
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.24708305123
# Relative B Error (OUT): -0.21852929508
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 7.56163110568 -- 41.7405490875
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (4.9931693422057206, -1.8545625956385761, -4.1920562957731455)
# B_mirror = 124.563733333
# K = 67.8525158936
# Start Phi: 5.92755701879
# Dipole L: 10.7635636337
# ================
# 0.818681158919
# Moving inner boundary in
# Relative B Error (IN): 0.19148492361
# Relative B Error (OUT): -0.273817706394
# ...
# ================
# 0.812575436349
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.554764402901
# Relative B Error (OUT): -0.420675777258
# ...
# ================
# 0.812575436349
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0195790765857
# Relative B Error (OUT): -0.201268241101
# ...
# ================
# 0.812575436349
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0699391477973
# Relative B Error (OUT): -0.0174027473877
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 10.1734201712 -- 53.5996501446
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (7.9576684781208362, 0.46050848891069546, -2.6998494703351335)
# B_mirror = 73.8710652786
# K = 2.28521866974
# Start Phi: 0.0578053048261
# Dipole L: 10.9555737981
# ================
# 0.82004430038
# Moving inner boundary in
# Relative B Error (IN): 0.00491285985376
# Relative B Error (OUT): -0.00448763785755
# ...
# ================
# 0.820938099172
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0934498249105
# Relative B Error (OUT): -0.00191765779279
# ...
# ================
# 0.820938099172
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0664206330567
# Relative B Error (OUT): -0.129379157668
# ...
# ================
# 0.820938099172
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0150390436799
# Relative B Error (OUT): -0.0799864357658
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 8.25725682731 -- 46.8558738232
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.8444319290900606, -2.991126394408985, 5.6660056274366326)
# Invalid line initiation
# Starting Location: [ 2.84443193 -2.99112639  5.66600563]
# LStar: nan -- 0.0669329166412
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (6.3942804444633845, -1.5649070396139002, -3.8551271392901665)
# B_mirror = 82.0436904035
# K = 7.21190664264
# Start Phi: 6.04316762845
# Dipole L: 10.6755301558
# ================
# 0.832226335657
# Moving inner boundary in
# Relative B Error (IN): 0.0129401399016
# Relative B Error (OUT): -0.0107415465206
# ...
# ================
# 0.823084265215
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.072048701144
# Relative B Error (OUT): -0.041118661911
# ...
# ================
# 0.823084265215
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.190477552664
# Relative B Error (OUT): -0.522685738978
# ...
# ================
# 0.823084265215
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0250822963804
# Relative B Error (OUT): -0.0841434328633
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 9.61908313623 -- 46.2903017998
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.6644051866382052, 1.7018931823480332, 1.4961739131412368)
# B_mirror = 444.317102264
# K = 41.1745155038
# Start Phi: 2.70679623033
# Dipole L: 4.91803897116
# ================
# 0.607391678212
# Moving inner boundary in
# Relative B Error (IN): 1.63736440311
# Relative B Error (OUT): -0.671974756828
# ...
# ================
# 0.610047796993
# Moving inner boundary in
# Relative B Error (IN): 0.651372486142
# Relative B Error (OUT): -2.34853774283
# ...
# ================
# 0.610047796993
# Moving inner boundary in
# Relative B Error (IN): 1.6685991364
# Relative B Error (OUT): -2.95985540608
# ...
# ================
# 0.610047796993
# Moving inner boundary in
# Relative B Error (IN): 2.01784628343
# Relative B Error (OUT): -1.31916121918
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 4.81820482949 -- 12.5650188923
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (0.80522133178031208, -2.7715900032034892, 3.7989104327585763)
# B_mirror = 457.183519753
# K = 379.851692812
# Start Phi: 4.99513231921
# Dipole L: 13.3418247432
# ================
# 0.85596626958
# Relative B Error (IN): 3.52600707788
# Relative B Error (OUT): -0.373697544263
# ...
# ================
# 0.841310533742
# Moving inner boundary in
# Relative B Error (IN): 4.13894304413
# Relative B Error (OUT): -1.36126548723
# ...
# ================
# 0.841310533742
# Moving inner boundary in
# Relative B Error (IN): 1.38658471744
# Relative B Error (OUT): -1.5177255926
# ...
# ================
# 0.841310533742
# Moving inner boundary in
# Relative B Error (IN): 3.43204804812
# Relative B Error (OUT): -1.73583863469
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 12.5134218615 -- 66.9019038677
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (3.6675687639867598, 1.2789053920982292, -2.4348650542218389)
# B_mirror = 421.006803314
# K = 97.713649415
# Start Phi: 0.335522095403
# Dipole L: 6.38815228754
# ================
# 0.686963356475
# Moving inner boundary in
# Relative B Error (IN): 3.84611850134
# Relative B Error (OUT): -0.270265847146
# ...
# ================
# 0.698142841798
# Moving inner boundary in
# Relative B Error (IN): 0.22351091511
# ...
# Moving inner boundary in
# Relative B Error (IN): 1.8320013216
# Relative B Error (OUT): -0.859774771907
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 7.35498032471 -- 37.664083004
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-1.1847827497369146, -3.0482386523100224, -5.0358478099684456)
# B_mirror = 249.664218286
# K = 597.146824
# Start Phi: 4.34168104726
# Dipole L: 28.3263205022
# ================
# 0.961062052935
# Out on EPS convergence
# Low: None
# High: None
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# Line Failed to Add in 4 line convergence
# Failure Mode: -999
# Phi: 0.0
# Est. L: 28.3263205022
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: nan -- 15.4376420975
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.7979419788981064, 0.22928663018745646, -6.4336454160399983)
# B_mirror = 121.520000243
# K = 1185.38672921
# Start Phi: 3.09384044526
# Dipole L: 17.3054096812
# ================
# 0.891304911381
# Out on EPS convergence
# Low: None
# High: None
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# Line Failed to Add in 4 line convergence
# Failure Mode: -999
# Phi: 0.0
# Est. L: 17.3054096812
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: nan -- 25.6379339695
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (5.4212410607756629, -0.24541861194157508, -5.6917824944012754)
# Invalid line initiation
# Starting Location: [ 5.42124106 -0.24541861 -5.69178249]
# LStar: nan -- 0.0582439899445
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (5.9260124013222359, 2.6354569234260339, 1.7250812547758321)
# B_mirror = 128.558639516
# K = 14.8927038923
# Start Phi: 0.418460141458
# Dipole L: 7.71704252787
# ================
# 0.736440450266
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.13883854675
# Relative B Error (OUT): -0.0775276011548
# ...
# ================
# 0.745685012125
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.226151121962
# Relative B Error (OUT): -0.0874147221404
# ...
# ================
# 0.745685012125
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.209526949925
# Relative B Error (OUT): -0.0341788188871
# ...
# ================
# 0.745685012125
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.460319239309
# Relative B Error (OUT): -0.474738564673
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 6.97304547233 -- 40.7040441036
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.8866438310524742, 0.45572896733296986, 3.2453177782969105)
# B_mirror = 223.093242635
# K = 139.865694067
# Start Phi: 3.04860151104
# Dipole L: 8.79954036312
# ================
# 0.769145311353
# Moving inner boundary in
# Relative B Error (IN): 0.218139295777
# Relative B Error (OUT): -1.59025781366
# ...
# ================
# 0.790158788613
# Moving inner boundary in
# Relative B Error (IN): 0.0708879874807
# Relative B Error (OUT): -0.288326958871
# ...
# ================
# 0.790158788613
# Moving inner boundary in
# Relative B Error (IN): 0.464861804598
# Relative B Error (OUT): -0.39056712782
# ...
# ================
# 0.790158788613
# Moving inner boundary in
# Relative B Error (IN): 0.215502690512
# Relative B Error (OUT): -0.221129294317
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 9.26020987177 -- 57.2064487934
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (1.2885489055974968, 3.7253122805658849, 4.7727094997916604)
# Invalid line initiation
# Starting Location: [ 1.28854891  3.72531228  4.7727095 ]
# LStar: nan -- 0.0694890022278
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-5.2831565664977616, 6.4851816423112902, -1.2802492222571817)
# B_mirror = 46.7473693429
# K = 2.80864448069
# Start Phi: 2.25440688822
# Dipole L: 8.32965897795
# ================
# 0.753529108638
# Relative B Error (IN): 0.119870290153
# Relative B Error (OUT): -0.0550823899518
# ...
# ================
# 0.846244909367
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0201216814481
# Relative B Error (OUT): -0.0112386889665
# ...
# ================
# 0.846244909367
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0724531776831
# Relative B Error (OUT): -0.00854250600987
# ...
# ================
# 0.846244909367
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0571109719643
# Relative B Error (OUT): -0.0359783478826
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 10.5029163221 -- 68.7214071751
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (1.5417736360075935, -2.4026659918608737, -0.15144266054174896)
# B_mirror = 1317.06291356
# K = 1.10514244514
# Start Phi: 5.28290220628
# Dipole L: 2.87254656588
# ================
# 0.38554553248
# Moving inner boundary in
# Relative B Error (IN): 0.642298639641
# Relative B Error (OUT): -0.0364225216706
# ...
# ================
# 0.380674341811
# Moving inner boundary in
# Relative B Error (IN): 1.03147793835
# Relative B Error (OUT): -0.283269119241
# ...
# ================
# 0.380674341811
# Moving inner boundary in
# Relative B Error (IN): 0.403350453736
# Relative B Error (OUT): -0.0200693326349
# ...
# ================
# 0.380674341811
# Moving inner boundary in
# Relative B Error (IN): 1.54307480075
# Relative B Error (OUT): -2.03567550651
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 2.86078586014 -- 3.95788192749
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (2.2967338890341509, 2.5788848513162108, 5.081291515948374)
# Invalid line initiation
# Starting Location: [ 2.29673389  2.57888485  5.08129152]
# LStar: nan -- 0.0888159275055
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-6.654652551019911, -1.461172212592353, -2.2568941048610172)
# B_mirror = 93.1653018902
# K = 22.9356339632
# Start Phi: 3.35773422816
# Dipole L: 7.84381744056
# ================
# 0.742200501424
# Moving inner boundary in
# Relative B Error (IN): 0.00603217153503
# Relative B Error (OUT): -0.0178717563097
# ...
# ================
# 0.816953907341
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.541182198036
# Relative B Error (OUT): -0.023374796636
# ...
# ================
# 0.816953907341
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0646687201678
# Relative B Error (OUT): -0.253692955189
# ...
# ================
# 0.816953907341
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0611790278061
# Relative B Error (OUT): -0.00301011404261
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 8.717310097 -- 49.0144128799
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (1.7444835654748605, 1.4431623139273901, 1.9873581753632727)
# B_mirror = 1762.15964987
# K = 281.206329505
# Start Phi: 0.69115038379
# Dipole L: 5.3205382194
# ================
# 0.660386016111
# Moving inner boundary in
# Relative B Error (IN): 1.90573883386
# Relative B Error (OUT): -4.13285484124
# ...
# ================
# 0.628445090768
# Moving inner boundary in
# Relative B Error (IN): 1.51643381675
# Relative B Error (OUT): -5.56356698238
# ...
# ================
# 0.628445090768
# Moving inner boundary in
# Relative B Error (IN): 13.2169435173
# Relative B Error (OUT): -0.899979477152
# ...
# ================
# 0.628445090768
# Moving inner boundary in
# Relative B Error (IN): 30.0218706215
# Relative B Error (OUT): -10.6650118232
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 5.04541439639 -- 15.2447860241
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (4.350045971159477, -2.1209073664282085, 5.118622260854484)
# Invalid line initiation
# Starting Location: [ 4.35004597 -2.12090737  5.11862226]
# LStar: nan -- 0.0689392089844
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (6.7435464603502719, 0.076270965637646196, 1.9704491052198037)
# B_mirror = 117.758060663
# K = 15.3633465499
# Start Phi: 0.0113097335529
# Dipole L: 8.44522817624
# ================
# 0.76676173639
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.10120697034
# Relative B Error (OUT): -0.0473822692829
# ...
# ================
# 0.753376428489
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.918565018998
# Relative B Error (OUT): -0.44460235347
# ...
# ================
# 0.753376428489
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0641555532753
# Relative B Error (OUT): -0.135664090841
# ...
# ================
# 0.753376428489
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.358773778061
# Relative B Error (OUT): -0.212694562255
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 7.20461460906 -- 36.8370709419
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (0.81991341017014552, 1.1557796170295251, -2.3598729664062867)
# B_mirror = 2617.76630047
# K = 956.388216438
# Start Phi: 0.95378752963
# Dipole L: 10.3718256782
# ================
# 0.817727837148
# Moving inner boundary in
# Moving outer boundary out
# Relative B Error (IN): 33.9278104987
# Relative B Error (OUT): -8.62640330323
# ...
# ================
# 0.791185320423
# Moving inner boundary in
# Moving outer boundary out
# Relative B Error (IN): 1.70719411622
# Relative B Error (OUT): -4.20552059885
# ...
# ================
# 0.791185320423
# Moving inner boundary in
# Relative B Error (IN): 6.33437194201
# Relative B Error (OUT): -0.640510161057
# ...
# ================
# 0.791185320423
# Moving inner boundary in
# Moving outer boundary out
# Relative B Error (IN): 8.62456551836
# Relative B Error (OUT): -3.26026887433
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 9.30133600707 -- 51.3074848652
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.5413322691817646, -1.7211064390753583, -6.7934861468243559)
# Invalid line initiation
# Starting Location: [-3.54133227 -1.72110644 -6.79348615]
# LStar: nan -- 0.0924999713898
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (5.536989441868192, 1.6237457587198507, 3.8503670719630305)
# B_mirror = 116.231294575
# K = 54.5598152083
# Start Phi: 0.285256612946
# Dipole L: 10.035501839
# ================
# 0.792329163481
# Moving inner boundary in
# Relative B Error (IN): 0.253674184451
# Relative B Error (OUT): -0.0285760089082
# ...
# ================
# 0.81178044289
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.830878389115
# Relative B Error (OUT): -0.52094629103
# ...
# ================
# 0.81178044289
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.154047241878
# Relative B Error (OUT): -0.382582408058
# ...
# ================
# 0.81178044289
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.00799044976512
# Relative B Error (OUT): -0.311453392966
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 8.98247066864 -- 54.7303590775
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-2.5027423403359443, 1.2436790357199918, 1.5344893752513489)
# B_mirror = 1238.47426916
# K = 104.225505178
# Start Phi: 2.68040685204
# Dipole L: 4.16782555102
# ================
# 0.552285268721
# Moving inner boundary in
# Relative B Error (IN): 1.85529349739
# Relative B Error (OUT): -1.86790983684
# ...
# ================
# 0.559134136814
# Moving inner boundary in
# Relative B Error (IN): 2.31318032288
# Relative B Error (OUT): -1.14615994558
# ...
# ================
# 0.559134136814
# Moving inner boundary in
# Relative B Error (IN): 1.74615930224
# Relative B Error (OUT): -1.76051735893
# ...
# ================
# 0.559134136814
# Moving inner boundary in
# Relative B Error (IN): 5.58323317203
# Relative B Error (OUT): -4.56222341814
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 3.92747306376 -- 8.1879658699
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-3.7340747667077778, -3.5242320138226275, 6.0754715481238009)
# B_mirror = 119.050151257
# K = 378.422500093
# Start Phi: 3.89808816457
# Dipole L: 27.1023649109
# ================
# 0.95437474356
# Out on EPS convergence
# Low: None
# High: None
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# Line Failed to Add in 4 line convergence
# Failure Mode: -999
# Phi: 0.0
# Est. L: 27.1023649109
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: nan -- 4.38913202286
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-0.73759576485988965, 6.4219703382966937, 3.3612444398226442)
# B_mirror = 111.488369486
# K = 69.3174687811
# Start Phi: 1.68515029939
# Dipole L: 10.0084043888
# ================
# 0.799469608048
# Moving inner boundary in
# Relative B Error (IN): 0.798205317154
# Relative B Error (OUT): -0.521058148928
# ...
# ================
# 0.819945352059
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.280643743147
# Relative B Error (OUT): -0.160019517491
# ...
# ================
# 0.819945352059
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.30512876167
# Relative B Error (OUT): -0.337372414023
# ...
# ================
# 0.819945352059
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.436194852906
# Relative B Error (OUT): -0.0593025938092
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 9.9367127266 -- 57.8381450176
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (-4.17206916657232, -2.3901401983662862, -6.9426649940866669)
# B_mirror = 103.537805613
# K = 877.143291656
# Start Phi: 3.66184039702
# Dipole L: 31.8069772071
# ================
# 0.982538989666
# Out on EPS convergence
# Low: None
# High: None
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# Line Failed to Add in 4 line convergence
# Failure Mode: -999
# Phi: 0.0
# Est. L: 31.8069772071
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: nan -- 5.58868980408
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (4.2959089614185784, 1.7321721908382215, 4.7733573095469977)
# B_mirror = 131.727081518
# K = 120.971988734
# Start Phi: 0.383274303738
# Dipole L: 12.0634398183
# ================
# 0.835948889832
# Moving inner boundary in
# Relative B Error (IN): 0.275936774728
# Relative B Error (OUT): -0.243992899412
# ...
# ================
# 0.839895549046
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0334083004436
# Relative B Error (OUT): -0.282364271642
# ...
# ================
# 0.839895549046
# Moving inner boundary in
# Moving inner boundary in
# Relative B Error (IN): 0.0092057576187
# Relative B Error (OUT): -0.0978430042706
# ...
# ================
# 0.839895549046
# Moving inner boundary in
# Relative B Error (IN): 0.10852093023
# Relative B Error (OUT): -0.0450822220116
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 11.1411193163 -- 74.9529359341
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# Calculating L*, K for point (3.1459156236965806, 1.380174641319202, -0.92146492842488825)
# B_mirror = 725.612919582
# K = 19.7150801198
# Start Phi: 0.413433593212
# Dipole L: 3.82745935777
# ================
# 0.526316913511
# Moving inner boundary in
# Relative B Error (IN): 0.245331168106
# Relative B Error (OUT): -0.143551736082
# ...
# ================
# 0.534663290371
# Moving inner boundary in
# Relative B Error (IN): 1.93114188924
# Relative B Error (OUT): -2.18521643181
# ...
# ================
# 0.534663290371
# Moving inner boundary in
# Relative B Error (IN): 0.73571074315
# Relative B Error (OUT): -1.63046510837
# ...
# ================
# 0.534663290371
# Moving inner boundary in
# Relative B Error (IN): 2.77782776814
# Relative B Error (OUT): -0.25723134534
# ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LStar: 3.69775966156 -- 7.199021101

# %%
s1 = StringIO.StringIO()
ps1 = pstats.Stats(profile, stream=s1)
ps1 = ps1.strip_dirs()
ps1.print_stats()
prof = s1.getvalue()
prof_lines1 = prof.split('\n')

profileDict = process_stats(prof_lines1, timeLine=0, keyLine=4, dataStartLine=6)

# %%
fig = plt.figure(figsize=(10, 8), facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
lprofile = profileDict['LShell.py']
y = []
y2 = []

xlab = []

n = float(lprofile['__init__']['ncalls'])
t = float(lprofile['__init__']['cumtime'])/n
for key in lprofile:
    if key == 'add_trace' or key == '__init__' or key == '__trace_from_location__' or key == 'l_star':
        xlab.append(key)
        y.append((float(lprofile[key]['cumtime'])/n)/t*100)

for key in lprofile:
    if key == 'add_trace' or key == '__init__' or key == '__trace_from_location__' or key == 'l_star':
        y2.append((float(lprofile[key]['cumtime'])/float(lprofile[key]['ncalls']))/t*100)

idx = np.arange(len(xlab))
idx_name = xlab

ax.bar(idx, y, align='center')
plt.xticks(idx, idx_name, rotation='vertical')

ax.set_ylabel("Time (%)")
ax.set_yscale('log')
ax.set_title("Average Execution Time per Method Call for a 4-point Converged $L^*$ Calculation\n For a Single Point")
ax.set_xlabel("Function Call")
s2 = StringIO.StringIO()
ps2 = pstats.Stats(profile, stream=s2)
ps2.print_stats('FieldLine.py:')
plt.grid(b=True, which='major', color='grey', linewidth=0.25, linestyle=':')

rects = ax.patches

# Now make some labels
labels = ["{:.3f} %".format(i) for i in y]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height/1.3, label, ha='center', va='bottom')

ax.bar(idx, y2, align='center', color='orange', width=rect.get_width()/1.5)

labels = ["{:.3f} %".format(i) for i in y2]
rects = ax.patches
for rect, label in zip(rects[4:], labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height/1.3, label, ha='center', va='bottom')
    if label == labels[3]:
        ax.text(rect.get_x() + rect.get_width()/2, height/1.6, "{:.2f} s".format(t), ha='center', va='bottom')


prof2 = s2.getvalue()
prof_lines = prof.split('\n')
fig.tight_layout()
fig.savefig("/Volumes/8TB Seagate/PhD Data/profiles/GHOSTpyProfile1pt.pdf")
# fig.savefig("/home/jmurphy/profiles/GHOSTpyProfile.pdf")

# %%
fig = plt.figure(figsize=(10, 8), facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
lprofile = profileDict['FieldLine.py']
y = []
y2 = []

xlab = []

lprofile = profileDict['LShell.py']

searchCount = float(lprofile['__search_B_adaptive__']['ncalls'])
t = float(lprofile['__search_B_adaptive__']['cumtime'])/searchCount

for key in lprofile:
    if key == 'get_raw_path' or key == '__search_B_adaptive__':
        xlab.append(key)
        y.append((float(lprofile[key]['cumtime'])/float(searchCount))/t*100)
        
lprofile = profileDict['FieldLine.py']
for key in lprofile:
    if key == '__trace_line__' or key == '__get_min_b_gap__':
        xlab.append(key)
        y.append((float(lprofile[key]['cumtime'])/float(searchCount))/t*100)
        
lprofile = profileDict['LShell.py']

for key in lprofile:
    if key == 'get_raw_path' or key == '__search_B_adaptive__':
        y2.append((float(lprofile[key]['cumtime'])/float(lprofile[key]['ncalls']))/t*100)
        
lprofile = profileDict['FieldLine.py']
for key in lprofile:
    if key == '__trace_line__' or key == '__get_min_b_gap__':
        y2.append((float(lprofile[key]['cumtime'])/float(lprofile[key]['ncalls']))/t*100)


idx = np.arange(len(xlab))
idx_name = xlab

ax.bar(idx, y, align='center')
plt.xticks(idx, idx_name, rotation='vertical')

ax.set_ylabel("Time (%)")
ax.set_yscale('log')
ax.set_title("Average Execution Time per Method Call for KB Line Search")
ax.set_xlabel("Function Call")
s2 = StringIO.StringIO()
ps2 = pstats.Stats(profile, stream=s2)
ps2.print_stats('FieldLine.py:')
plt.grid(b=True, which='major', color='grey', linewidth=0.25, linestyle=':')

rects = ax.patches

# Now make some labels
labels = ["{:.4f} %".format(i) for i in y]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height/1.6, label, ha='center', va='bottom')

ax.bar(idx, y2, align='center', color='orange', width=rect.get_width()/1.5)

labels = ["{:.4f} %".format(i) for i in y2]
rects = ax.patches
for rect, label in zip(rects[4:], labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height/1.6, label, ha='center', va='bottom')
    if label == labels[1]:
        ax.text(rect.get_x() + rect.get_width()/2, height/2.3, "{:.4f} s".format(t), ha='center', va='bottom')




prof2 = s2.getvalue()
prof_lines = prof.split('\n')
fig.tight_layout()
fig.savefig("/Volumes/8TB Seagate/PhD Data/profiles/GHOSTpyProfileKBSearch.pdf")
# fig.savefig("/home/jmurphy/profiles/GHOSTpyProfile.pdf")

# %%
fig = plt.figure(figsize=(10, 8), facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
y = []
y2 = []

xlab = []

lprofile = profileDict['FieldLine.py']
searchCount = float(lprofile['__init__']['ncalls'])
t = float(lprofile['__init__']['cumtime'])/searchCount


keyList = ['__init__',  '__k_mod__', '__trace_line__']

for key in lprofile:
    if key in keyList:
        xlab.append(key)
        y.append((float(lprofile[key]['cumtime'])/float(searchCount))/t*100)
                
for key in lprofile:
    if key in keyList:
        y2.append((float(lprofile[key]['cumtime'])/float(lprofile[key]['ncalls']))/t*100)


idx = np.arange(len(xlab))
idx_name = xlab

ax.bar(idx, y, align='center')
plt.xticks(idx, idx_name, rotation='vertical')

ax.set_ylabel("Time (%)")
ax.set_yscale('log')
ax.set_title("Average Execution Time per Method Call for Field Line Trace and $K$ Model")
ax.set_xlabel("Function Call")
s2 = StringIO.StringIO()
ps2 = pstats.Stats(profile, stream=s2)
ps2.print_stats('FieldLine.py:')
plt.grid(b=True, which='major', color='grey', linewidth=0.25, linestyle=':')

rects = ax.patches

# Now make some labels
labels = ["{:.3f} %".format(i) for i in y]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height/1.10, label, ha='center', va='bottom')

ax.bar(idx, y2, align='center', color='orange', width=rect.get_width()/1.5)

labels = ["{:.3f} %".format(i) for i in y2]
rects = ax.patches
for rect, label in zip(rects[3:], labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height/1.10, label, ha='center', va='bottom')
    if label == labels[2]:
        ax.text(rect.get_x() + rect.get_width()/2, height/1.17, "{:.2f} s".format(t), ha='center', va='bottom')


prof2 = s2.getvalue()
prof_lines = prof.split('\n')
fig.tight_layout()
fig.savefig("/Volumes/8TB Seagate/PhD Data/profiles/GHOSTpyProfileFLine.pdf")
# fig.savefig("/home/jmurphy/profiles/GHOSTpyProfile.pdf")

# %%
wnan = ~np.isnan(lstars)
lstars2 = lstars[np.where(wnan)]
timings2 = timings[np.where(wnan)]

# %%
fig = plt.figure(figsize=(10, 5), facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_title("Histogram of Calculated $L^*$ Values")
ax.set_xlabel("$L^*$")

ax.hist(lstars2, bins='auto')
plt.grid(b=True, which='major', color='grey', linewidth=0.25, linestyle=':')
plt.tight_layout()

fig.savefig("/Volumes/8TB Seagate/PhD Data/profiles/histL.pdf")

# %%
fig = plt.figure(figsize=(10, 5), facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax.set_title("Histogram of Execution Time for Calculated $L^*$ Values")
ax.set_xlabel("Execution Time (s)")

ax.hist(timings2, bins='auto')
plt.grid(b=True, which='major', color='grey', linewidth=0.25, linestyle=':')
plt.tight_layout()
fig.savefig("/Volumes/8TB Seagate/PhD Data/profiles/histT.pdf")

# %%
np.nanmedian(timings2)
# Out:
# 36.391512513160706

# %%
np.nanmean(timings2)
# Out:
# 36.745554879307747
